# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import copy
import itertools
from scipy import linalg as sLA
from numpy import linalg as LA
import time
from copy import deepcopy
from scipy.stats import unitary_group
import cmath
from matplotlib import pyplot as plt
import scipy
import scipy.special
import random


import sys
sys.path.append("../scripts")



from Gates import *
from functions import *
from state import *
from Unitary import *

# %% [markdown]
# # Классические одномерные случайные блуждания:

# %%
# Defines all of the necessary parameters

N = 50    # Defines the total number of steps our walker will take
pr = 0.5  # Defines the probability of our walker stepping to the right
i = 0     # Defines the initial position of our walker

def random_walk(pr, N, i):

    position = i

    # Repeatedly queries our random variable and moves our walker for the specified number of steps

    for j in range(0, N): 

        coin_flip = list(np.random.choice(2, 1, p=[1-pr, pr])) # Flips our weighted coin
        position += 2*coin_flip[0]-1 # Moves our walker according to the coin flip 

    return position

print("The walker is located at: x = {var}".format(var = random_walk(pr, N, i)))
# Out:
# The walker is located at: x = 18

# %%
def dist(runs, N):

    positions = range(-1*N, N+1)
    instances = [0 for i in range(-1*N, N+1)]

    for k in range(0, runs):

        result = random_walk(pr, N, i)
        instances[positions.index(result)] += 1

    plt.bar(positions, [n/runs for n in instances])
    plt.show()

dist(10000, N)

# %%
def height_calculate(x, N, pr):

    a = (N + x)/2
    b = (N - x)/2

    if (x%2 == 0):
        var = scipy.special.binom(N, a)*(pr**a)*((1-pr)**b)
    else:
        var = 0
    return var

positions = range(-1*N, N+1)
heights = [height_calculate(x, N, pr) for x in positions]
plt.bar(positions, heights)
plt.show()

# %%
run_range = [50, 100, 500, 1000, 5000, 10000]
for run in run_range:
    dist(run, N)

# %% [markdown]
# # Квантовые блуждания

# %%
def Addition_operator(state, wires):
    N = len(wires)
    
    for wire in wires[1:]:
        state.apply_U(X(), [wire])
#         print(state.get_coefs())
    
    for wire in reversed(range(1,N)):
        local_wires = np.array(list(range(wire+1)))
        print(local_wires, wire)
        state.apply_U(X(), [wire])
#         print(state.get_coefs())
        state.apply_long_Toffoli(axis = local_wires)
#         print(state.get_coefs())
        
def Subtraction_operator(state, wires):
    N = len(wires)
    
    for wire in range(1,N):
        local_wires = np.array(list(range(wire+1)))
#         print(local_wires, wire)
#         print(state.get_coefs())
        state.apply_long_Toffoli(axis = local_wires)
#         print(state.get_coefs())
        state.apply_U(X(), [wire])
#         print(state.get_coefs())
    
    for wire in wires[1:]:
        state.apply_U(X(), [wire])
#         print(state.get_coefs())

# %%
def step(state, wires):
    state.apply_U(H(), [0])
    Subtraction_operator(state, wires)
#     state.apply_U(X(), [0])
    Addition_operator(state, wires)
#     state.apply_U(X(), [0])
#     print(state.get_coefs())
    
def Quantum_walk_linear(state, steps):
    state0 = copy.deepcopy(state)
    for s in range(steps):
        step(state0, wires = list(range(state.N)))
        
    return state0

def projection(a,b):
    a = np.array(a)
    b = np.array(b)
    
    a = a/np.sum(a*a.conj())
    b = b/np.sum(b*b.conj())
    
    p = np.dot(a,b)
    
    return p

def get_statistics(coefs):

    projection_list = []
    num_list = []
    vec_list = []
    for i in range(0, len(coefs)):
        
        num_list.append(i)
        vec = np.zeros(len(coefs))
        vec[i] = 1
#         vec = str(bin(i))[2:]
#         vec = '0'*(len(coefs)-len(vec)) + vec
#         vec = np.array(list(vec)).astype('int')
        vec_list.append(vec)
        projection_list.append(projection(coefs,vec)**2)
        
    res = np.array([num_list, projection_list])
        
    return res

# %%
random.seed(2)

n = 3
state0 = Qpsi(1)
state1 = Qpsi(n)
state = Qpsi(n+1)

state0.build_zero_state()
# state1.build_random_state()
state1.build_zero_state()

state.set_coefs(np.kron(state0.get_coefs(), state1.get_coefs()))

init_w_coefs = state1.get_coefs()
init_coefs = state.get_coefs()
print(state0.get_coefs(),state1.get_coefs(), state.get_coefs())
# Out:
# [1.+0.j 0.+0.j] [1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j] [1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]

# %%
print(state.get_coefs())
Addition_operator(state, wires = [0,1,2,3])
print(state.get_coefs())
Subtraction_operator(state, wires = [0,1,2,3])
print(state.get_coefs())
# Out:
# [1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
# [0 1 2 3] 3
# [4, 0, 1]
# [0 1 2] 2
# [0 1] 1
# [1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
# [0 1] 1
# [1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
# [1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
# [0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
# [0 1 2] 2
# [0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
# [0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
# [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
# [0 1 2 3] 3
# [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
# [4, 0, 1]
# [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
# [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
# [1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]

# %%
steps = 5
res_state = Quantum_walk_linear(state, steps)
# Out:
# [0 1] 1
# [0.70710678+0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.70710678+0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j]
# [0.70710678+0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.70710678+0.j 0.        +0.j 0.        +0.j 0.        +0.j]
# [0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.70710678+0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.70710678+0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j]
# [0 1 2] 2
# [0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.70710678+0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.70710678+0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j]
# [0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.70710678+0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.70710678+0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j]
# [0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.70710678+0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.70710678+0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j]
# [0 1 2 3] 3
# [0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.70710678+0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.70710678+0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j]
# [2, 3, 0]
# [4, 0, 1]
# [1, 5]
# [4, 0, 1]
# [0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.70710678+0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.70710678+0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j]
# [0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.70710678+0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.70710678+0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j]
# [0 1 2 3] 3
# [2, 3, 0]
# [4, 0, 1]
# [1, 5]
# [4, 0, 1]
# [0 1 2] 2
# [0 1] 1
# [0 1] 1
# [1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
# [1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
# [0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
# [0 1 2] 2
# [0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
# [0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
# [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
# [0 1 2 3] 3
# [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
# [2, 3, 0]
# [4, 0, 1]
# [1, 5]
# [4, 0, 1]
# [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
# [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
# [0 1 2 3] 3
# [2, 3, 0]
# [4, 0, 1]
# [1, 5]
# [4, 0, 1]
# [0 1 2] 2
# [0 1] 1
# [0 1] 1
# [0.70710678+0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.70710678+0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j]
# [0.70710678+0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.70710678+0.j 0.        +0.j 0.        +0.j 0.        +0.j]
# [0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.70710678+0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.70710678+0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j]
# [0 1 2] 2
# [0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.70710678+0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.70710678+0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j]
# [0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.70710678+0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.70710678+0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j]
# [0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.70710678+0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.70710678+0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j]
# [0 1 2 3] 3
# [0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.70710678+0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.70710678+0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j]
# [2, 3, 0]
# [4, 0, 1]
# [1, 5]
# [4, 0, 1]
# [0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.70710678+0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.70710678+0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j]
# [0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.70710678+0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.70710678+0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j]
# [0 1 2 3] 3
# [2, 3, 0]
# [4, 0, 1]
# [1, 5]
# [4, 0, 1]
# [0 1 2] 2
# [0 1] 1
# [0 1] 1
# [1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
# [1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
# [0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
# [0 1 2] 2
# [0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
# [0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
# [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
# [0 1 2 3] 3
# [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
# [2, 3, 0]
# [4, 0, 1]
# [1, 5]
# [4, 0, 1]
# [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
# [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
# [0 1 2 3] 3
# [2, 3, 0]
# [4, 0, 1]
# [1, 5]
# [4, 0, 1]
# [0 1 2] 2
# [0 1] 1
# [0 1] 1
# [0.70710678+0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.70710678+0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j]
# [0.70710678+0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.70710678+0.j 0.        +0.j 0.        +0.j 0.        +0.j]
# [0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.70710678+0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.70710678+0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j]
# [0 1 2] 2
# [0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.70710678+0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.70710678+0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j]
# [0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.70710678+0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.70710678+0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j]
# [0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.70710678+0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.70710678+0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j]
# [0 1 2 3] 3
# [0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.70710678+0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.70710678+0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j]
# [2, 3, 0]
# [4, 0, 1]
# [1, 5]
# [4, 0, 1]
# [0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.70710678+0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.70710678+0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j]
# [0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.70710678+0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.70710678+0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j]
# [0 1 2 3] 3
# [2, 3, 0]
# [4, 0, 1]
# [1, 5]
# [4, 0, 1]
# [0 1 2] 2
# [0 1] 1

# %%
res_state.split_system(1, n)

coefs_B = res_state.get_B_coefs()
res_B = get_statistics(coefs_B)

coefs = res_state.get_coefs()
res = get_statistics(coefs)
init_res = get_statistics(init_coefs)

# %%
plt.plot(init_res[0], init_res[1])
plt.show()
plt.plot(res[0], res[1])
plt.show()
plt.plot(res_B[0], res_B[1])
plt.show()
# Out:
# /home/stas/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /home/stas/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /home/stas/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# # Проверка работы Тоффоли

# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append("../scripts")



from Gates import *
from functions import *
from state import *
from Unitary import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
state = Qpsi(4)
state.build_zero_state()
print(state.get_coefs())
state.apply_U(X(), [0])
state.apply_U(X(), [1])
state.apply_U(X(), [2])
state.apply_U(X(), [3])

print(state.get_coefs() - apply_long_Toffoli(state.get_coefs(), wires = [0,1,2,3]))
# Out:
# [1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
# [4, 0, 1]
# [ 0.+0.00000000e+00j  0.+0.00000000e+00j  0.+0.00000000e+00j
#   0.+0.00000000e+00j  0.+0.00000000e+00j  0.+0.00000000e+00j
#   0.+0.00000000e+00j  0.+0.00000000e+00j  0.+0.00000000e+00j
#   0.+0.00000000e+00j  0.+0.00000000e+00j  0.+0.00000000e+00j
#   0.+0.00000000e+00j  0.+0.00000000e+00j -1.+7.21644966e-16j
#   1.-1.74315280e-32j]

# %%
state = Qpsi(3)
state.build_zero_state()
print(state.get_coefs())
# state.apply_U(X(), [0])
state.apply_U(X(), [1])
state.apply_U(X(), [2])
print(state.get_coefs(), apply_Toffoli(state.get_coefs(), axis = [1,2,0]))
# Out:
# [1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
# [0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j] [ 0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j -3.92523115e-17+1.17756934e-16j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  1.00000000e+00-2.22044605e-16j]
